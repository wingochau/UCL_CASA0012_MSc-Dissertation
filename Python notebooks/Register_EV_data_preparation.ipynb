# %%
# Import packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
import seaborn as sns
from datetime import datetime

# %%
# Read the dataset

# %%
reg_2013 = pd.read_csv('DATA/REG/2013.csv')
reg_2014 = pd.read_csv('DATA/REG/2014.csv')
reg_2015 = pd.read_csv('DATA/REG/2015.csv')
reg_2016 = pd.read_csv('DATA/REG/2016.csv')
reg_2017 = pd.read_csv('DATA/REG/2017.csv')

reg_0118 = pd.read_csv('DATA/REG/0118.csv')
reg_0218 = pd.read_csv('DATA/REG/0218.csv')
reg_0318 = pd.read_csv('DATA/REG/0318.csv')
reg_0418 = pd.read_csv('DATA/REG/0418.csv')
reg_0518 = pd.read_csv('DATA/REG/0518.csv')
reg_0618 = pd.read_csv('DATA/REG/0618.csv')
reg_0718 = pd.read_csv('DATA/REG/0718.csv')
reg_0818 = pd.read_csv('DATA/REG/0818.csv')
reg_0818 = pd.read_csv('DATA/REG/0818.csv')
reg_0918 = pd.read_csv('DATA/REG/0918.csv')
reg_1018 = pd.read_csv('DATA/REG/1018.csv')
reg_1118 = pd.read_csv('DATA/REG/1018.csv')
reg_1218 = pd.read_csv('DATA/REG/1018.csv')

reg_0119 = pd.read_csv('DATA/REG/0119.csv')
reg_0219 = pd.read_csv('DATA/REG/0219.csv')
reg_0319 = pd.read_csv('DATA/REG/0319.csv')
reg_0419 = pd.read_csv('DATA/REG/0419.csv')
reg_0519 = pd.read_csv('DATA/REG/0519.csv')
reg_0619 = pd.read_csv('DATA/REG/0619.csv')
reg_0719 = pd.read_csv('DATA/REG/0719.csv')
reg_0819 = pd.read_csv('DATA/REG/0819.csv')
reg_0919 = pd.read_csv('DATA/REG/0919.csv')
reg_1019 = pd.read_csv('DATA/REG/1019.csv')
reg_1119 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/1119.csv')
reg_1219 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/1219.csv')

reg_0120 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0120.csv')
reg_0220 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0220.csv')
reg_0320 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0320.csv')
reg_0420 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0420.csv')
reg_0520 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0520.csv')
reg_0620 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0620.csv')
reg_0720 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0720.csv')
reg_0820 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0820.csv')
reg_0920 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0920.csv')
reg_1020 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/1020.csv')
reg_1120 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/1120.csv')
reg_1220 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/1220.csv')


#reg_0121 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0121.csv')
#reg_0221 = pd.read_csv('https://raw.githubusercontent.com/wingochau/Dissertation/main/0221.csv')
#reg_0321 = pd.read_csv('DATA/REG/0321.csv')
#reg_0421 = pd.read_csv('DATA/REG/0421.csv')

# %%
reg_0320.head(3)
# Out:
#                         Unnamed: 0  Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                              NaN         NaN        NaN        NaN
# 1   電單車 (無邊卡)\nMotor Cycles (Solo)         NaN        NaN        NaN
# 2  電單車 (連邊卡)\nMotor Cycles (Combo)         NaN        NaN        NaN
#
#        Petrol Unnamed: 5      Diesel Unnamed: 7    Electric Unnamed: 9  \
# 0  Registered   Licensed  Registered   Licensed  Registered   Licensed
# 1     84 954     57 697           -          -           18         13
# 2         113         84          -          -           -          -
#
#        LP Gas Unnamed: 11 Unnamed: 12  Others (1) Unnamed: 14       Total  \
# 0  Registered         NaN    Licensed  Registered    Licensed  Registered
# 1          -          NaN          -           -           -      84 972
# 2          -          NaN          -           -           -          113
#
#   Unnamed: 16
# 0    Licensed
# 1     57 710
# 2          84

# %%
pet_0118 = reg_0118.iloc[11,4]
pet_0218 = reg_0218.iloc[11,4]
pet_0318 = reg_0318.iloc[11,4]
pet_0418 = reg_0418.iloc[11,4]
pet_0518 = reg_0518.iloc[11,4]
pet_0618 = reg_0618.iloc[11,4]
pet_0718 = reg_0718.iloc[11,4]
pet_0818 = reg_0818.iloc[11,4]
pet_0918 = reg_0918.iloc[11,4]
pet_1018 = reg_1018.iloc[11,4]
pet_1118 = reg_1118.iloc[11,4]
pet_1218 = reg_1218.iloc[11,4]


pet_0119 = reg_0119.iloc[11,4]
pet_0219 = reg_0219.iloc[11,4]
pet_0319 = reg_0319.iloc[11,4]
pet_0419 = reg_0419.iloc[11,4]
pet_0519 = reg_0519.iloc[11,4]
pet_0619 = reg_0619.iloc[11,4]
pet_0719 = reg_0719.iloc[11,4]
pet_0819 = reg_0819.iloc[11,4]
pet_0919 = reg_0919.iloc[11,4]
pet_1019 = reg_1019.iloc[11,4]
pet_1119 = reg_1119.iloc[4,4]
pet_1219 = reg_1219.iloc[4,4]

pet_0120 = reg_0120.iloc[4,4]
pet_0220 = reg_0220.iloc[4,4]
pet_0320 = reg_0320.iloc[4,4]
pet_0420 = reg_0420.iloc[4,4]
pet_0520 = reg_0520.iloc[4,4]
pet_0620 = reg_0620.iloc[4,4]
pet_0720 = reg_0720.iloc[4,4]
pet_0820 = reg_0820.iloc[4,4]
pet_0920 = reg_0920.iloc[4,4]
pet_1020 = reg_1020.iloc[4,4]
pet_1120 = reg_1120.iloc[4,4]
pet_1220 = reg_1220.iloc[4,4]

#pet_0121 = reg_0121.iloc[4,4]
#pet_0221 = reg_0221.iloc[4,4]
#pet_0321 = reg_0321.iloc[11,4]
#pet_0421 = reg_0421.iloc[11,4]

# %%
die_0118 = reg_0118.iloc[11,6]
die_0218 = reg_0218.iloc[11,6]
die_0318 = reg_0318.iloc[11,6]
die_0418 = reg_0418.iloc[11,6]
die_0518 = reg_0518.iloc[11,6]
die_0618 = reg_0618.iloc[11,6]
die_0718 = reg_0718.iloc[11,6]
die_0818 = reg_0818.iloc[11,6]
die_0918 = reg_0918.iloc[11,6]
die_1018 = reg_1018.iloc[11,6]
die_1118 = reg_1118.iloc[11,6]
die_1218 = reg_1218.iloc[11,6]


die_0119 = reg_0119.iloc[11,6]
die_0219 = reg_0219.iloc[11,6]
die_0319 = reg_0319.iloc[11,6]
die_0419 = reg_0419.iloc[11,6]
die_0519 = reg_0519.iloc[11,6]
die_0619 = reg_0619.iloc[11,6]
die_0719 = reg_0719.iloc[11,6]
die_0819 = reg_0819.iloc[11,6]
die_0919 = reg_0919.iloc[11,6]
die_1019 = reg_1019.iloc[11,6]
die_1119 = reg_1119.iloc[4,6]
die_1219 = reg_1219.iloc[4,6]

die_0120 = reg_0120.iloc[4,6]
die_0220 = reg_0220.iloc[4,6]
die_0320 = reg_0320.iloc[4,6]
die_0420 = reg_0420.iloc[4,6]
die_0520 = reg_0520.iloc[4,6]
die_0620 = reg_0620.iloc[4,6]
die_0720 = reg_0720.iloc[4,6]
die_0820 = reg_0820.iloc[4,6]
die_0920 = reg_0920.iloc[4,6]
die_1020 = reg_1020.iloc[4,6]
die_1120 = reg_1120.iloc[4,6]
die_1220 = reg_1220.iloc[4,6]

#die_0121 = reg_0121.iloc[4,6]
#die_0221 = reg_0221.iloc[4,6]
#die_0321 = reg_0321.iloc[11,6]
#die_0421 = reg_0421.iloc[11,6]

# %%
reg_0118_EV = reg_0118.iloc[11,8]
reg_0218_EV = reg_0218.iloc[11,8]
reg_0318_EV = reg_0318.iloc[11,8]
reg_0418_EV = reg_0418.iloc[11,8]
reg_0518_EV = reg_0518.iloc[11,8]
reg_0618_EV = reg_0618.iloc[11,8]
reg_0718_EV = reg_0718.iloc[11,8]
reg_0818_EV = reg_0818.iloc[11,8]
reg_0918_EV = reg_0918.iloc[11,8]
reg_1018_EV = reg_1018.iloc[11,8]
reg_1118_EV = reg_1118.iloc[11,8]
reg_1218_EV = reg_1218.iloc[11,8]


reg_0119_EV = reg_0119.iloc[11,8]
reg_0219_EV = reg_0219.iloc[11,8]
reg_0319_EV = reg_0319.iloc[11,8]
reg_0419_EV = reg_0419.iloc[11,8]
reg_0519_EV = reg_0519.iloc[11,8]
reg_0619_EV = reg_0619.iloc[11,8]
reg_0719_EV = reg_0719.iloc[11,8]
reg_0819_EV = reg_0819.iloc[11,8]
reg_0919_EV = reg_0919.iloc[11,8]
reg_1019_EV = reg_1019.iloc[11,8]
reg_1119_EV = reg_1119.iloc[4,8]
reg_1219_EV = reg_1219.iloc[4,8]

reg_0120_EV = reg_0120.iloc[4,8]
reg_0220_EV = reg_0220.iloc[4,8]
reg_0320_EV = reg_0320.iloc[4,8]
reg_0420_EV = reg_0420.iloc[4,8]
reg_0520_EV = reg_0520.iloc[4,8]
reg_0620_EV = reg_0620.iloc[4,8]
reg_0720_EV = reg_0720.iloc[4,8]
reg_0820_EV = reg_0820.iloc[4,8]
reg_0920_EV = reg_0920.iloc[4,8]
reg_1020_EV = reg_1020.iloc[4,8]
reg_1120_EV = reg_1120.iloc[4,8]
reg_1220_EV = reg_1220.iloc[4,8]

#reg_0121_EV = reg_0121.iloc[4,8]
#reg_0221_EV = reg_0221.iloc[4,8]
#reg_0321_EV = reg_0321.iloc[11,8]
#reg_0421_EV = reg_0421.iloc[11,8]

# %% [markdown]
# # Dealing with spaces in string

# %%
# Remove the space in the field for Petrol & make it to be a dataframe format with index
## 2018
pet_0118 = pet_0118.replace(" ", "")
pet_0118 = int(pet_0118)
p_0118 = {'PETROL': [pet_0118]}
pf_0118 = pd.DataFrame(data=p_0118)
pf_0118.index.name = 'Index'

pet_0218 = pet_0218.replace(" ", "")
pet_0218 = int(pet_0218)
p_0218 = {'PETROL': [pet_0218]}
pf_0218 = pd.DataFrame(data=p_0218)
pf_0218.index.name = 'Index'

pet_0318 = pet_0318.replace(" ", "")
pet_0318 = int(pet_0318)
p_0318 = {'PETROL': [pet_0318]}
pf_0318 = pd.DataFrame(data=p_0318)
pf_0318.index.name = 'Index'

pet_0418 = pet_0418.replace(" ", "")
pet_0418 = int(pet_0418)
p_0418 = {'PETROL': [pet_0418]}
pf_0418 = pd.DataFrame(data=p_0418)
pf_0418.index.name = 'Index'

pet_0518 = pet_0518.replace(" ", "")
pet_0518 = int(pet_0518)
p_0518 = {'PETROL': [pet_0518]}
pf_0518 = pd.DataFrame(data=p_0518)
pf_0518.index.name = 'Index'

pet_0618 = pet_0618.replace(" ", "")
pet_0618 = int(pet_0618)
p_0618 = {'PETROL': [pet_0618]}
pf_0618 = pd.DataFrame(data=p_0618)
pf_0618.index.name = 'Index'

pet_0718 = pet_0718.replace(" ", "")
pet_0718 = int(pet_0718)
p_0718 = {'PETROL': [pet_0718]}
pf_0718 = pd.DataFrame(data=p_0718)
pf_0718.index.name = 'Index'

pet_0818 = pet_0818.replace(" ", "")
pet_0818 = int(pet_0818)
p_0818 = {'PETROL': [pet_0818]}
pf_0818 = pd.DataFrame(data=p_0818)
pf_0818.index.name = 'Index'

pet_0918 = pet_0918.replace(" ", "")
pet_0918 = int(pet_0918)
p_0918 = {'PETROL': [pet_0918]}
pf_0918 = pd.DataFrame(data=p_0918)
pf_0918.index.name = 'Index'

pet_1018 = pet_1018.replace(" ", "")
pet_1018 = int(pet_1018)
p_1018 = {'PETROL': [pet_1018]}
pf_1018 = pd.DataFrame(data=p_1018)
pf_1018.index.name = 'Index'

pet_1118 = pet_1118.replace(" ", "")
pet_1118 = int(pet_1118)
p_1118 = {'PETROL': [pet_1118]}
pf_1118 = pd.DataFrame(data=p_1118)
pf_1118.index.name = 'Index'

pet_1218 = pet_1218.replace(" ", "")
pet_1218 = int(pet_1218)
p_1218 = {'PETROL': [pet_1218]}
pf_1218 = pd.DataFrame(data=p_1218)
pf_1218.index.name = 'Index'


## 2019
pet_0119 = pet_0119.replace(" ", "")
pet_0119 = int(pet_0119)
p_0119 = {'PETROL': [pet_0119]}
pf_0119 = pd.DataFrame(data=p_0119)
pf_0119.index.name = 'Index'

pet_0219 = pet_0219.replace(" ", "")
pet_0219 = int(pet_0219)
p_0219 = {'PETROL': [pet_0219]}
pf_0219 = pd.DataFrame(data=p_0219)
pf_0219.index.name = 'Index'

pet_0319 = pet_0319.replace(" ", "")
pet_0319 = int(pet_0319)
p_0319 = {'PETROL': [pet_0319]}
pf_0319 = pd.DataFrame(data=p_0319)
pf_0319.index.name = 'Index'

pet_0419 = pet_0419.replace(" ", "")
pet_0419 = int(pet_0419)
p_0419 = {'PETROL': [pet_0419]}
pf_0419 = pd.DataFrame(data=p_0419)
pf_0419.index.name = 'Index'

pet_0519 = pet_0519.replace(" ", "")
pet_0519 = int(pet_0519)
p_0519 = {'PETROL': [pet_0519]}
pf_0519 = pd.DataFrame(data=p_0519)
pf_0519.index.name = 'Index'

pet_0619 = pet_0619.replace(" ", "")
pet_0619 = int(pet_0619)
p_0619 = {'PETROL': [pet_0619]}
pf_0619 = pd.DataFrame(data=p_0619)
pf_0619.index.name = 'Index'

pet_0719 = pet_0719.replace(" ", "")
pet_0719 = int(pet_0719)
p_0719 = {'PETROL': [pet_0719]}
pf_0719 = pd.DataFrame(data=p_0719)
pf_0719.index.name = 'Index'

pet_0819 = pet_0819.replace(" ", "")
pet_0819 = int(pet_0819)
p_0819 = {'PETROL': [pet_0819]}
pf_0819 = pd.DataFrame(data=p_0819)
pf_0819.index.name = 'Index'

pet_0919 = pet_0919.replace(" ", "")
pet_0919 = int(pet_0919)
p_0919 = {'PETROL': [pet_0919]}
pf_0919 = pd.DataFrame(data=p_0919)
pf_0919.index.name = 'Index'

pet_1019 = pet_1019.replace(" ", "")
pet_1019 = int(pet_1019)
p_1019 = {'PETROL': [pet_1019]}
pf_1019 = pd.DataFrame(data=p_1019)
pf_1019.index.name = 'Index'

pet_1119 = pet_1119.replace(" ", "")
pet_1119 = int(pet_1119)
p_1119 = {'PETROL': [pet_1119]}
pf_1119 = pd.DataFrame(data=p_1119)
pf_1119.index.name = 'Index'

pet_1219 = pet_1219.replace(" ", "")
pet_1219 = int(pet_1219)
p_1219 = {'PETROL': [pet_1219]}
pf_1219 = pd.DataFrame(data=p_1219)
pf_1219.index.name = 'Index'


## 2020
pet_0120 = pet_0120.replace(" ", "")
pet_0120 = int(pet_0120)
p_0120 = {'PETROL': [pet_0120]}
pf_0120 = pd.DataFrame(data=p_0120)
pf_0120.index.name = 'Index'

pet_0220 = pet_0220.replace(" ", "")
pet_0220 = int(pet_0220)
p_0220 = {'PETROL': [pet_0220]}
pf_0220 = pd.DataFrame(data=p_0220)
pf_0220.index.name = 'Index'

pet_0320 = pet_0320.replace(" ", "")
pet_0320 = int(pet_0320)
p_0320 = {'PETROL': [pet_0320]}
pf_0320 = pd.DataFrame(data=p_0320)
pf_0320.index.name = 'Index'

pet_0420 = pet_0420.replace(" ", "")
pet_0420 = int(pet_0420)
p_0420 = {'PETROL': [pet_0420]}
pf_0420 = pd.DataFrame(data=p_0420)
pf_0420.index.name = 'Index'

pet_0520 = pet_0520.replace(" ", "")
pet_0520 = int(pet_0520)
p_0520 = {'PETROL': [pet_0520]}
pf_0520 = pd.DataFrame(data=p_0520)
pf_0520.index.name = 'Index'

pet_0620 = pet_0620.replace(" ", "")
pet_0620 = int(pet_0620)
p_0620 = {'PETROL': [pet_0620]}
pf_0620 = pd.DataFrame(data=p_0620)
pf_0620.index.name = 'Index'

pet_0720 = pet_0720.replace(" ", "")
pet_0720 = int(pet_0720)
p_0720 = {'PETROL': [pet_0720]}
pf_0720 = pd.DataFrame(data=p_0720)
pf_0720.index.name = 'Index'

pet_0820 = pet_0820.replace(" ", "")
pet_0820 = int(pet_0820)
p_0820 = {'PETROL': [pet_0820]}
pf_0820 = pd.DataFrame(data=p_0820)
pf_0820.index.name = 'Index'

pet_0920 = pet_0920.replace(" ", "")
pet_0920 = int(pet_0920)
p_0920 = {'PETROL': [pet_0920]}
pf_0920 = pd.DataFrame(data=p_0920)
pf_0920.index.name = 'Index'

pet_1020 = pet_1020.replace(" ", "")
pet_1020 = int(pet_1020)
p_1020 = {'PETROL': [pet_1020]}
pf_1020 = pd.DataFrame(data=p_1020)
pf_1020.index.name = 'Index'

pet_1120 = pet_1120.replace(" ", "")
pet_1120 = int(pet_1120)
p_1120 = {'PETROL': [pet_1120]}
pf_1120 = pd.DataFrame(data=p_1120)
pf_1120.index.name = 'Index'
 
pet_1220 = pet_1220.replace(" ", "")
pet_1220 = int(pet_1220)
p_1220 = {'PETROL': [pet_1220]}
pf_1220 = pd.DataFrame(data=p_1220)
pf_1220.index.name = 'Index'

## 2021
#pet_0121 = pet_0121.replace(" ", "")
#pet_0121 = int(pet_0121)
#p_0121 = {'PETROL': [pet_0121]}
#pf_0121 = pd.DataFrame(data=p_0121)
#pf_0121.index.name = 'Index'

#pet_0221 = pet_0221.replace(" ", "")
#pet_0221 = int(pet_0221)
#p_0221 = {'PETROL': [pet_0221]}
#pf_0221 = pd.DataFrame(data=p_0221)
#pf_0221.index.name = 'Index'

#pet_0321 = pet_0321.replace(" ", "")
#pet_0321 = int(pet_0321)
#p_0321 = {'PETROL': [pet_0321]}
#pf_0321 = pd.DataFrame(data=p_0321)
#pf_0321.index.name = 'Index'

#pet_0421 = pet_0421.replace(" ", "")
#pet_0421 = int(pet_0421)
#p_0421 = {'PETROL': [pet_0421]}
#pf_0421 = pd.DataFrame(data=p_0421)
#pf_0421.index.name = 'Index'

# %%
## 2018
die_0118 = die_0118.replace(" ", "")
die_0118 = int(die_0118)
di_0118 = {'DIESEL': [die_0118]}
dif_0118 = pd.DataFrame(data=di_0118)
dif_0118.index.name = 'Index'

die_0218 = die_0218.replace(" ", "")
die_0218 = int(die_0218)
di_0218 = {'DIESEL': [die_0218]}
dif_0218 = pd.DataFrame(data=di_0218)
dif_0218.index.name = 'Index'

die_0318 = die_0318.replace(" ", "")
die_0318 = int(die_0318)
di_0318 = {'DIESEL': [die_0318]}
dif_0318 = pd.DataFrame(data=di_0318)
dif_0318.index.name = 'Index'

die_0418 = die_0418.replace(" ", "")
die_0418 = int(die_0418)
di_0418 = {'DIESEL': [die_0418]}
dif_0418 = pd.DataFrame(data=di_0418)
dif_0418.index.name = 'Index'

die_0518 = die_0518.replace(" ", "")
die_0518 = int(die_0518)
di_0518 = {'DIESEL': [die_0518]}
dif_0518 = pd.DataFrame(data=di_0518)
dif_0518.index.name = 'Index'

die_0618 = die_0618.replace(" ", "")
die_0618 = int(die_0618)
di_0618 = {'DIESEL': [die_0618]}
dif_0618 = pd.DataFrame(data=di_0618)
dif_0618.index.name = 'Index'

die_0718 = die_0718.replace(" ", "")
die_0718 = int(die_0718)
di_0718 = {'DIESEL': [die_0718]}
dif_0718 = pd.DataFrame(data=di_0718)
dif_0718.index.name = 'Index'

die_0818 = die_0818.replace(" ", "")
die_0818 = int(die_0818)
di_0818 = {'DIESEL': [die_0818]}
dif_0818 = pd.DataFrame(data=di_0818)
dif_0818.index.name = 'Index'

die_0918 = die_0918.replace(" ", "")
die_0918 = int(die_0918)
di_0918 = {'DIESEL': [die_0918]}
dif_0918 = pd.DataFrame(data=di_0918)
dif_0918.index.name = 'Index'

die_1018 = die_1018.replace(" ", "")
die_1018 = int(die_1018)
di_1018 = {'DIESEL': [die_1018]}
dif_1018 = pd.DataFrame(data=di_1018)
dif_1018.index.name = 'Index'

die_1118 = die_1118.replace(" ", "")
die_1118 = int(die_1118)
di_1118 = {'DIESEL': [die_1118]}
dif_1118 = pd.DataFrame(data=di_1118)
dif_1118.index.name = 'Index'
 
die_1218 = die_1218.replace(" ", "")
die_1218 = int(die_1218)
di_1218 = {'DIESEL': [die_1218]}
dif_1218 = pd.DataFrame(data=di_1218)
dif_1218.index.name = 'Index'

## 2019
die_0119 = die_0119.replace(" ", "")
die_0119 = int(die_0119)
di_0119 = {'DIESEL': [die_0119]}
dif_0119 = pd.DataFrame(data=di_0119)
dif_0119.index.name = 'Index'

die_0219 = die_0219.replace(" ", "")
die_0219 = int(die_0219)
di_0219 = {'DIESEL': [die_0219]}
dif_0219 = pd.DataFrame(data=di_0219)
dif_0219.index.name = 'Index'

die_0319 = die_0319.replace(" ", "")
die_0319 = int(die_0319)
di_0319 = {'DIESEL': [die_0319]}
dif_0319 = pd.DataFrame(data=di_0319)
dif_0319.index.name = 'Index'

die_0419 = die_0419.replace(" ", "")
die_0419 = int(die_0419)
di_0419 = {'DIESEL': [die_0419]}
dif_0419 = pd.DataFrame(data=di_0419)
dif_0419.index.name = 'Index'

die_0519 = die_0519.replace(" ", "")
die_0519 = int(die_0519)
di_0519 = {'DIESEL': [die_0519]}
dif_0519 = pd.DataFrame(data=di_0519)
dif_0519.index.name = 'Index'

die_0619 = die_0619.replace(" ", "")
die_0619 = int(die_0619)
di_0619 = {'DIESEL': [die_0619]}
dif_0619 = pd.DataFrame(data=di_0619)
dif_0619.index.name = 'Index'

die_0719 = die_0719.replace(" ", "")
die_0719 = int(die_0719)
di_0719 = {'DIESEL': [die_0719]}
dif_0719 = pd.DataFrame(data=di_0719)
dif_0719.index.name = 'Index'

die_0819 = die_0819.replace(" ", "")
die_0819 = int(die_0819)
di_0819 = {'DIESEL': [die_0819]}
dif_0819 = pd.DataFrame(data=di_0819)
dif_0819.index.name = 'Index'

die_0919 = die_0919.replace(" ", "")
die_0919 = int(die_0919)
di_0919 = {'DIESEL': [die_0919]}
dif_0919 = pd.DataFrame(data=di_0919)
dif_0919.index.name = 'Index'

die_1019 = die_1019.replace(" ", "")
die_1019 = int(die_1019)
di_1019 = {'DIESEL': [die_1019]}
dif_1019 = pd.DataFrame(data=di_1019)
dif_1019.index.name = 'Index'

die_1119 = die_1119.replace(" ", "")
die_1119 = int(die_1119)
di_1119 = {'DIESEL': [die_1119]}
dif_1119 = pd.DataFrame(data=di_1119)
dif_1119.index.name = 'Index'
 
die_1219 = die_1219.replace(" ", "")
die_1219 = int(die_1219)
di_1219 = {'DIESEL': [die_1219]}
dif_1219 = pd.DataFrame(data=di_1219)
dif_1219.index.name = 'Index'


## 2020
die_0120 = die_0120.replace(" ", "")
die_0120 = int(die_0120)
di_0120 = {'DIESEL': [die_0120]}
dif_0120 = pd.DataFrame(data=di_0120)
dif_0120.index.name = 'Index'

die_0220 = die_0220.replace(" ", "")
die_0220 = int(die_0220)
di_0220 = {'DIESEL': [die_0220]}
dif_0220 = pd.DataFrame(data=di_0220)
dif_0220.index.name = 'Index'

die_0320 = die_0320.replace(" ", "")
die_0320 = int(die_0320)
di_0320 = {'DIESEL': [die_0320]}
dif_0320 = pd.DataFrame(data=di_0320)
dif_0320.index.name = 'Index'

die_0420 = die_0420.replace(" ", "")
die_0420 = int(die_0420)
di_0420 = {'DIESEL': [die_0420]}
dif_0420 = pd.DataFrame(data=di_0420)
dif_0420.index.name = 'Index'

die_0520 = die_0520.replace(" ", "")
die_0520 = int(die_0520)
di_0520 = {'DIESEL': [die_0520]}
dif_0520 = pd.DataFrame(data=di_0520)
dif_0520.index.name = 'Index'

die_0620 = die_0620.replace(" ", "")
die_0620 = int(die_0620)
di_0620 = {'DIESEL': [die_0620]}
dif_0620 = pd.DataFrame(data=di_0620)
dif_0620.index.name = 'Index'

die_0720 = die_0720.replace(" ", "")
die_0720 = int(die_0720)
di_0720 = {'DIESEL': [die_0720]}
dif_0720 = pd.DataFrame(data=di_0720)
dif_0720.index.name = 'Index'

die_0820 = die_0820.replace(" ", "")
die_0820 = int(die_0820)
di_0820 = {'DIESEL': [die_0820]}
dif_0820 = pd.DataFrame(data=di_0820)
dif_0820.index.name = 'Index'

die_0920 = die_0920.replace(" ", "")
die_0920 = int(die_0920)
di_0920 = {'DIESEL': [die_0920]}
dif_0920 = pd.DataFrame(data=di_0920)
dif_0920.index.name = 'Index'

die_1020 = die_1020.replace(" ", "")
die_1020 = int(die_1020)
di_1020 = {'DIESEL': [die_1020]}
dif_1020 = pd.DataFrame(data=di_1020)
dif_1020.index.name = 'Index'

die_1120 = die_1120.replace(" ", "")
die_1120 = int(die_1120)
di_1120 = {'DIESEL': [die_1120]}
dif_1120 = pd.DataFrame(data=di_1120)
dif_1120.index.name = 'Index'
 
die_1220 = die_1220.replace(" ", "")
die_1220 = int(die_1220)
di_1220 = {'DIESEL': [die_1220]}
dif_1220 = pd.DataFrame(data=di_1220)
dif_1220.index.name = 'Index'

## 2021
#die_0121 = die_0121.replace(" ", "")
#die_0121 = int(die_0121)
#di_0121 = {'DIESEL': [die_0121]}
#dif_0121 = pd.DataFrame(data=di_0121)
#dif_0121.index.name = 'Index'

#die_0221 = die_0221.replace(" ", "")
#die_0221 = int(die_0221)
#di_0221 = {'DIESEL': [die_0221]}
#dif_0221 = pd.DataFrame(data=di_0221)
#dif_0221.index.name = 'Index'

#die_0321 = die_0321.replace(" ", "")
#die_0321 = int(die_0321)
#di_0321 = {'DIESEL': [die_0321]}
#dif_0321 = pd.DataFrame(data=di_0321)
#dif_0321.index.name = 'Index'

#die_0421 = die_0421.replace(" ", "")
#die_0421 = int(die_0421)
#di_0421 = {'DIESEL': [die_0421]}
#dif_0421 = pd.DataFrame(data=di_0421)
#dif_0421.index.name = 'Index'

# %%
## 2018
reg_0118_EV = reg_0118_EV.replace(" ", "")
reg_0118_EV = int(reg_0118_EV)
d_0118 = {'EV': [reg_0118_EV]}
df_0118 = pd.DataFrame(data=d_0118)
df_0118.index.name = 'Index'

reg_0218_EV = reg_0218_EV.replace(" ", "")
reg_0218_EV = int(reg_0218_EV)
d_0218 = {'EV': [reg_0218_EV]}
df_0218 = pd.DataFrame(data=d_0218)
df_0218.index.name = 'Index'

reg_0318_EV = reg_0318_EV.replace(" ", "")
reg_0318_EV = int(reg_0318_EV)
d_0318 = {'EV': [reg_0318_EV]}
df_0318 = pd.DataFrame(data=d_0318)
df_0318.index.name = 'Index'

reg_0418_EV = reg_0418_EV.replace(" ", "")
reg_0418_EV = int(reg_0418_EV)
d_0418 = {'EV': [reg_0418_EV]}
df_0418 = pd.DataFrame(data=d_0418)
df_0418.index.name = 'Index'

reg_0518_EV = reg_0518_EV.replace(" ", "")
reg_0518_EV = int(reg_0518_EV)
d_0518 = {'EV': [reg_0518_EV]}
df_0518 = pd.DataFrame(data=d_0518)
df_0518.index.name = 'Index'

reg_0618_EV = reg_0618_EV.replace(" ", "")
reg_0618_EV = int(reg_0618_EV)
d_0618 = {'EV': [reg_0618_EV]}
df_0618 = pd.DataFrame(data=d_0618)
df_0618.index.name = 'Index'

reg_0718_EV = reg_0718_EV.replace(" ", "")
reg_0718_EV = int(reg_0718_EV)
d_0718 = {'EV': [reg_0718_EV]}
df_0718 = pd.DataFrame(data=d_0718)
df_0718.index.name = 'Index'

reg_0818_EV = reg_0818_EV.replace(" ", "")
reg_0818_EV = int(reg_0818_EV)
d_0818 = {'EV': [reg_0818_EV]}
df_0818 = pd.DataFrame(data=d_0818)
df_0818.index.name = 'Index'

reg_0918_EV = reg_0918_EV.replace(" ", "")
reg_0918_EV = int(reg_0918_EV)
d_0918 = {'EV': [reg_0918_EV]}
df_0918 = pd.DataFrame(data=d_0918)
df_0918.index.name = 'Index'

reg_1018_EV = reg_1018_EV.replace(" ", "")
reg_1018_EV = int(reg_1018_EV)
d_1018 = {'EV': [reg_1018_EV]}
df_1018 = pd.DataFrame(data=d_1018)
df_1018.index.name = 'Index'

reg_1118_EV = reg_1118_EV.replace(" ", "")
reg_1118_EV = int(reg_1118_EV)
d_1118 = {'EV': [reg_1118_EV]}
df_1118 = pd.DataFrame(data=d_1118)
df_1118.index.name = 'Index'

reg_1218_EV = reg_1218_EV.replace(" ", "")
reg_1218_EV = int(reg_1218_EV)
d_1218 = {'EV': [reg_1218_EV]}
df_1218 = pd.DataFrame(data=d_1218)
df_1218.index.name = 'Index'


## 2019
reg_0119_EV = reg_0119_EV.replace(" ", "")
reg_0119_EV = int(reg_0119_EV)
d_0119 = {'EV': [reg_0119_EV]}
df_0119 = pd.DataFrame(data=d_0119)
df_0119.index.name = 'Index'

reg_0219_EV = reg_0219_EV.replace(" ", "")
reg_0219_EV = int(reg_0219_EV)
d_0219 = {'EV': [reg_0219_EV]}
df_0219 = pd.DataFrame(data=d_0219)
df_0219.index.name = 'Index'

reg_0319_EV = reg_0319_EV.replace(" ", "")
reg_0319_EV = int(reg_0319_EV)
d_0319 = {'EV': [reg_0319_EV]}
df_0319 = pd.DataFrame(data=d_0319)
df_0319.index.name = 'Index'

reg_0419_EV = reg_0419_EV.replace(" ", "")
reg_0419_EV = int(reg_0419_EV)
d_0419 = {'EV': [reg_0419_EV]}
df_0419 = pd.DataFrame(data=d_0419)
df_0419.index.name = 'Index'

reg_0519_EV = reg_0519_EV.replace(" ", "")
reg_0519_EV = int(reg_0519_EV)
d_0519 = {'EV': [reg_0519_EV]}
df_0519 = pd.DataFrame(data=d_0519)
df_0519.index.name = 'Index'

reg_0619_EV = reg_0619_EV.replace(" ", "")
reg_0619_EV = int(reg_0619_EV)
d_0619 = {'EV': [reg_0619_EV]}
df_0619 = pd.DataFrame(data=d_0619)
df_0619.index.name = 'Index'

reg_0719_EV = reg_0719_EV.replace(" ", "")
reg_0719_EV = int(reg_0719_EV)
d_0719 = {'EV': [reg_0719_EV]}
df_0719 = pd.DataFrame(data=d_0719)
df_0719.index.name = 'Index'

reg_0819_EV = reg_0819_EV.replace(" ", "")
reg_0819_EV = int(reg_0819_EV)
d_0819 = {'EV': [reg_0819_EV]}
df_0819 = pd.DataFrame(data=d_0819)
df_0819.index.name = 'Index'

reg_0919_EV = reg_0919_EV.replace(" ", "")
reg_0919_EV = int(reg_0919_EV)
d_0919 = {'EV': [reg_0919_EV]}
df_0919 = pd.DataFrame(data=d_0919)
df_0919.index.name = 'Index'

reg_1019_EV = reg_1019_EV.replace(" ", "")
reg_1019_EV = int(reg_1019_EV)
d_1019 = {'EV': [reg_1019_EV]}
df_1019 = pd.DataFrame(data=d_1019)
df_1019.index.name = 'Index'

reg_1119_EV = reg_1119_EV.replace(" ", "")
reg_1119_EV = int(reg_1119_EV)
d_1119 = {'EV': [reg_1119_EV]}
df_1119 = pd.DataFrame(data=d_1119)
df_1119.index.name = 'Index'

reg_1219_EV = reg_1219_EV.replace(" ", "")
reg_1219_EV = int(reg_1219_EV)
d_1219 = {'EV': [reg_1219_EV]}
df_1219 = pd.DataFrame(data=d_1219)
df_1219.index.name = 'Index'


## 2020
reg_0120_EV = reg_0120_EV.replace(" ", "")
reg_0120_EV = int(reg_0120_EV)
d_0120 = {'EV': [reg_0120_EV]}
df_0120 = pd.DataFrame(data=d_0120)
df_0120.index.name = 'Index'

reg_0220_EV = reg_0220_EV.replace(" ", "")
reg_0220_EV = int(reg_0220_EV)
d_0220 = {'EV': [reg_0220_EV]}
df_0220 = pd.DataFrame(data=d_0220)
df_0220.index.name = 'Index'

reg_0320_EV = reg_0320_EV.replace(" ", "")
reg_0320_EV = int(reg_0320_EV)
d_0320 = {'EV': [reg_0320_EV]}
df_0320 = pd.DataFrame(data=d_0320)
df_0320.index.name = 'Index'

reg_0420_EV = reg_0420_EV.replace(" ", "")
reg_0420_EV = int(reg_0420_EV)
d_0420 = {'EV': [reg_0420_EV]}
df_0420 = pd.DataFrame(data=d_0420)
df_0420.index.name = 'Index'

reg_0520_EV = reg_0520_EV.replace(" ", "")
reg_0520_EV = int(reg_0520_EV)
d_0520 = {'EV': [reg_0520_EV]}
df_0520 = pd.DataFrame(data=d_0520)
df_0520.index.name = 'Index'

reg_0620_EV = reg_0620_EV.replace(" ", "")
reg_0620_EV = int(reg_0620_EV)
d_0620 = {'EV': [reg_0620_EV]}
df_0620 = pd.DataFrame(data=d_0620)
df_0620.index.name = 'Index'

reg_0720_EV = reg_0720_EV.replace(" ", "")
reg_0720_EV = int(reg_0720_EV)
d_0720 = {'EV': [reg_0720_EV]}
df_0720 = pd.DataFrame(data=d_0720)
df_0720.index.name = 'Index'

reg_0820_EV = reg_0820_EV.replace(" ", "")
reg_0820_EV = int(reg_0820_EV)
d_0820 = {'EV': [reg_0820_EV]}
df_0820 = pd.DataFrame(data=d_0820)
df_0820.index.name = 'Index'

reg_0920_EV = reg_0920_EV.replace(" ", "")
reg_0920_EV = int(reg_0920_EV)
d_0920 = {'EV': [reg_0920_EV]}
df_0920 = pd.DataFrame(data=d_0920)
df_0920.index.name = 'Index'

reg_1020_EV = reg_1020_EV.replace(" ", "")
reg_1020_EV = int(reg_1020_EV)
d_1020 = {'EV': [reg_1020_EV]}
df_1020 = pd.DataFrame(data=d_1020)
df_1020.index.name = 'Index'

reg_1120_EV = reg_1120_EV.replace(" ", "")
reg_1120_EV = int(reg_1120_EV)
d_1120 = {'EV': [reg_1120_EV]}
df_1120 = pd.DataFrame(data=d_1120)
df_1120.index.name = 'Index'

reg_1220_EV = reg_1220_EV.replace(" ", "")
reg_1220_EV = int(reg_1220_EV)
d_1220 = {'EV': [reg_1220_EV]}
df_1220 = pd.DataFrame(data=d_1220)
df_1220.index.name = 'Index'

## 2021
#reg_0121_EV = reg_0121_EV.replace(" ", "")
#reg_0121_EV = int(reg_0121_EV)
#d_0121 = {'EV': [reg_0121_EV]}
#df_0121 = pd.DataFrame(data=d_0121)
#df_0121.index.name = 'Index'

#reg_0221_EV = reg_0221_EV.replace(" ", "")
#reg_0221_EV = int(reg_0221_EV)
#d_0221 = {'EV': [reg_0221_EV]}
#df_0221 = pd.DataFrame(data=d_0221)
#df_0221.index.name = 'Index'

#reg_0321_EV = reg_0321_EV.replace(" ", "")
#reg_0321_EV = int(reg_0321_EV)
#d_0321 = {'EV': [reg_0321_EV]}
#df_0321 = pd.DataFrame(data=d_0321)
#df_0321.index.name = 'Index'

#reg_0421_EV = reg_0421_EV.replace(" ", "")
#reg_0421_EV = int(reg_0421_EV)
#d_0421 = {'EV': [reg_0421_EV]}
#df_0421 = pd.DataFrame(data=d_0421)
#df_0421.index.name = 'Index'

# %%
## 2018
s_0118 = pd.merge(pd.merge(df_0118,pf_0118,on='Index'),dif_0118,on='Index')
s_0218 = pd.merge(pd.merge(df_0218,pf_0218,on='Index'),dif_0218,on='Index')
s_0318 = pd.merge(pd.merge(df_0318,pf_0318,on='Index'),dif_0318,on='Index')
s_0418 = pd.merge(pd.merge(df_0418,pf_0418,on='Index'),dif_0418,on='Index')
s_0518 = pd.merge(pd.merge(df_0518,pf_0518,on='Index'),dif_0518,on='Index')
s_0618 = pd.merge(pd.merge(df_0618,pf_0618,on='Index'),dif_0618,on='Index')
s_0718 = pd.merge(pd.merge(df_0718,pf_0718,on='Index'),dif_0718,on='Index')
s_0818 = pd.merge(pd.merge(df_0818,pf_0818,on='Index'),dif_0818,on='Index')
s_0918 = pd.merge(pd.merge(df_0918,pf_0918,on='Index'),dif_0918,on='Index')
s_1018 = pd.merge(pd.merge(df_1018,pf_1018,on='Index'),dif_1018,on='Index')
s_1118 = pd.merge(pd.merge(df_1118,pf_1118,on='Index'),dif_1118,on='Index')
s_1218 = pd.merge(pd.merge(df_1218,pf_1218,on='Index'),dif_1218,on='Index')

## 2019
s_0119 = pd.merge(pd.merge(df_0119,pf_0119,on='Index'),dif_0119,on='Index')
s_0219 = pd.merge(pd.merge(df_0219,pf_0219,on='Index'),dif_0219,on='Index')
s_0319 = pd.merge(pd.merge(df_0319,pf_0319,on='Index'),dif_0319,on='Index')
s_0419 = pd.merge(pd.merge(df_0419,pf_0419,on='Index'),dif_0419,on='Index')
s_0519 = pd.merge(pd.merge(df_0519,pf_0519,on='Index'),dif_0519,on='Index')
s_0619 = pd.merge(pd.merge(df_0619,pf_0619,on='Index'),dif_0619,on='Index')
s_0719 = pd.merge(pd.merge(df_0719,pf_0719,on='Index'),dif_0719,on='Index')
s_0819 = pd.merge(pd.merge(df_0819,pf_0819,on='Index'),dif_0819,on='Index')
s_0919 = pd.merge(pd.merge(df_0919,pf_0919,on='Index'),dif_0919,on='Index')
s_1019 = pd.merge(pd.merge(df_1019,pf_1019,on='Index'),dif_1019,on='Index')
s_1119 = pd.merge(pd.merge(df_1119,pf_1119,on='Index'),dif_1119,on='Index')
s_1219 = pd.merge(pd.merge(df_1219,pf_1219,on='Index'),dif_1219,on='Index')


## 2020
s_0120 = pd.merge(pd.merge(df_0120,pf_0120,on='Index'),dif_0120,on='Index')
s_0220 = pd.merge(pd.merge(df_0220,pf_0220,on='Index'),dif_0220,on='Index')
s_0320 = pd.merge(pd.merge(df_0320,pf_0320,on='Index'),dif_0320,on='Index')
s_0420 = pd.merge(pd.merge(df_0420,pf_0420,on='Index'),dif_0420,on='Index')
s_0520 = pd.merge(pd.merge(df_0520,pf_0520,on='Index'),dif_0520,on='Index')
s_0620 = pd.merge(pd.merge(df_0620,pf_0620,on='Index'),dif_0620,on='Index')
s_0720 = pd.merge(pd.merge(df_0720,pf_0720,on='Index'),dif_0720,on='Index')
s_0820 = pd.merge(pd.merge(df_0820,pf_0820,on='Index'),dif_0820,on='Index')
s_0920 = pd.merge(pd.merge(df_0920,pf_0920,on='Index'),dif_0920,on='Index')
s_1020 = pd.merge(pd.merge(df_1020,pf_1020,on='Index'),dif_1020,on='Index')
s_1120 = pd.merge(pd.merge(df_1120,pf_1120,on='Index'),dif_1120,on='Index')
s_1220 = pd.merge(pd.merge(df_1220,pf_1220,on='Index'),dif_1220,on='Index')

## 2021
#s_0121 = pd.merge(pd.merge(df_0121,pf_0121,on='Index'),dif_0121,on='Index')
#s_0221 = pd.merge(pd.merge(df_0221,pf_0221,on='Index'),dif_0221,on='Index')
#s_0321 = pd.merge(pd.merge(df_0321,pf_0321,on='Index'),dif_0321,on='Index')
#s_0421 = pd.merge(pd.merge(df_0421,pf_0421,on='Index'),dif_0421,on='Index')

# %% [markdown]
# # Adding a period to each csv

# %%
## 2018
s_0118['period'] = '201801'
s_0218['period'] = '201802'
s_0318['period'] = '201803'
s_0418['period'] = '201804'
s_0518['period'] = '201805'
s_0618['period'] = '201806'
s_0718['period'] = '201807'
s_0818['period'] = '201808'
s_0918['period'] = '201809'
s_1018['period'] = '201810'
s_1118['period'] = '201811'
s_1218['period'] = '201812'


## 2019
s_0119['period'] = '201901'
s_0219['period'] = '201902'
s_0319['period'] = '201903'
s_0419['period'] = '201904'
s_0519['period'] = '201905'
s_0619['period'] = '201906'
s_0719['period'] = '201907'
s_0819['period'] = '201908'
s_0919['period'] = '201909'
s_1019['period'] = '201910'
s_1119['period'] = '201911'
s_1219['period'] = '201912'

## 2020
s_0120['period'] = '202001'
s_0220['period'] = '202002'
s_0320['period'] = '202003'
s_0420['period'] = '202004'
s_0520['period'] = '202005'
s_0620['period'] = '202006'
s_0720['period'] = '202007'
s_0820['period'] = '202008'
s_0920['period'] = '202009'
s_1020['period'] = '202010'
s_1120['period'] = '202011'
s_1220['period'] = '202012'

## 2021
#s_0121['period'] = '202101'
#s_0221['period'] = '202102'
#s_0321['period'] = '202103'
#s_0421['period'] = '202104'

# %% [markdown]
# # Concatenating different month into one year

# %%
reg_2013['period'] = reg_2013['period'].astype(str)
reg_2014['period'] = reg_2014['period'].astype(str)
reg_2015['period'] = reg_2015['period'].astype(str)
reg_2016['period'] = reg_2016['period'].astype(str)
reg_2017['period'] = reg_2017['period'].astype(str)

list_2018 = [s_0218, s_0318, s_0418, s_0518, s_0618, s_0718, s_0818,s_0918,s_1018, s_1118, s_1218]
reg_2018 = s_0118.append(list_2018, ignore_index=True)

list_2019 = [s_0219, s_0319, s_0419, s_0519, s_0619, s_0719, s_0819,s_0919,s_1019, s_1119, s_1219]
reg_2019 = s_0119.append(list_2019, ignore_index=True)

list_2020 = [s_0220, s_0320, s_0420, s_0520, s_0620, s_0720, s_0820,s_0920,s_1020, s_1120, s_1220]
reg_2020 = s_0120.append(list_2020, ignore_index=True)

#list_2021 = [s_0221, s_0321, s_0421]
#reg_2021 = s_0121.append(list_2021, ignore_index=True)

# %%
list_reg = [reg_2020, reg_2018, reg_2017, reg_2016, reg_2015,reg_2014, reg_2013]
reg_ev_sum = reg_2019.append(list_reg, ignore_index=True)
reg_ev_sum.shape
# Out:
# (96, 4)

# %%
# Order by period 
reg_ev_sum = reg_ev_sum.sort_values(by=['period'])
reg_ev_sum = reg_ev_sum.reset_index(drop=True)
reg_ev_sum
# Out:
#        EV  PETROL  DIESEL  period
# 0     292  494222    2291  201301
# 1     297  495909    2292  201302
# 2     297  498394    2296  201303
# 3     303  499553    2292  201304
# 4     304  501271    2294  201305
# ..    ...     ...     ...     ...
# 91  15878  612808   11970  202008
# 92  16324  615024   11971  202009
# 93  16417  617320   11971  202010
# 94  17186  618935   11970  202011
# 95  17998  621288   11968  202012
#
# [96 rows x 4 columns]

# %%
#reg_ev_sum.to_csv('ML_registered_vehicle_sum.csv')
